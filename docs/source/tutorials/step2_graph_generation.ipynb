# %% [markdown]
# # Generate Feature Matrix and Adjacency Matrix
#
# Generate the **feature matrix** and **adjacency matrix** using the raw exon read counts and raw junction read counts obtained from the count files. For detailed instructions on aligning the RNA-seq data, refer to the following tutorials:
#
# - **Full-length RNA-seq**: [step1_1_preprocess_full_length.md](./step1_1_preprocess_full_length.md)
# - **10X RNA-seq**: [step1_2_preprocess_10X.md](step1_2_preprocess_10X.md)
#
# Before running this section, please ensure that your counts data and metadata file is ready, and also make sure you have the `dolphin_adj_index.csv` and `dolphin.exon.pkl` files prepared. These files can be generated in this [file](./step0_generate_exon_gtf_final.ipynb).
#
# > 💡 **Note:** These two files are paired — the `.pkl` file contains exon-level information, and the `dolphin_adj_index.csv` stores adjacency location data.
# > The exon order in the adjacency index file matches the exon order in the pickle file. **They must be used together.**
#
# For human GRCh38, you can directly download the necessary files from [here](https://mcgill-my.sharepoint.com/:f:/g/personal/kailu_song_mail_mcgill_ca/EvZtHeW7qjJJs_RHc2-327ABeLXafa-ruvfk9Vs134crig?e=TsGsk8).
#
# ### Metadata File Format
#
# The metadata file should be tab-separated, with the **"CB"** (cell barcode) column as the only mandatory column. You can add as many metadata columns as needed. These additional metadata columns will be retained in all output `adata` files as **obs** (observations).
#
# | CB                      | cluster           |
# |--------------------------|-------------------|
# | T8_AAAGCAAGTCGCGAAA      | Stellate cell     |
# | T8_AAATGCCAGCTGGAAC      | Macrophage cell   |
# | T8_AAATGCCGTAGCTGCC      | Macrophage cell   |
# | T8_AAATGCCTCCACTGGG      | Ductal cell type 2|
# | ...                      | ...               |
#
# **Notes:**
# - The **"CB"** column is mandatory as it represents the cell barcode.
# - Additional columns (e.g., **cluster**, **source**, etc.) can be added based on the specific metadata required for your analysis.
# - These metadata columns will be included in the output `adata` files under **obs**.
# - **"CB"** will be used to find the **count table file names** and will be stored as **obs index** in `adata`.

# %% [markdown]
# > ⚠️ **For demonstration purposes**, the following example is run directly in this Jupyter Notebook.
# > For better performance and scalability, especially on large datasets, we recommend running the full pipeline via the [step2_1_graph_generation.py](https://github.com/mcgilldinglab/DOLPHIN/blob/main/docs/source/tutorials/step2_1_graph_generation.py) script.

# %%
from DOLPHIN.graph_generation.preprocess_raw_reads import run_parallel_gene_processing

# %%
### This function processes exon count and junction raw count data for each cell and converts them into
### flattened feature and adjacency vectors.

run_parallel_gene_processing(
    metadata_path="/fsla_meta.csv",
    gtf_path="./dolphin_exon_gtf/dolphin.exon.pkl",
    adj_index_path="./dolphin_exon_gtf/dolphin_adj_index.csv",
    main_folder="./",
    n_processes=8
)
# Out:
# Starting Raw Reads Processing...
# INFO:DOLPHIN.graph_generation.preprocess_raw_reads:Running gene processing using 8 processes...
# Sample =  SRR18379095 , Gene id =  ENSG00000000457 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000000460 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000000938 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000001036 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000001084 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000001497 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000001630 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000001631 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000002549 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000002586 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000002834 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000003056 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000003400 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000003402 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000003756 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000004059 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000004139 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000004142 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000
is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100147 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100162 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100196 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100201 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100219 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100220 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100226 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100239 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100241 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100242 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100246 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100258 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100288 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100297 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100299 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100300 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100304 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100307 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100314 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100316 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100319 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100335 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100342 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100345 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100347 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100348 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100353 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100354 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100359 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100360 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100376 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100380 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100385 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100387 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100412 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100413 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100425 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100426 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100427 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100429 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100439 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100441 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100445 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100450 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100485 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100490 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100503 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000100519 is running.
# ...
# Sample =  SRR18379095 , Gene id =  ENSG00000284731 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284734 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284746 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284773 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284776 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284803 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284862 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284964 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000284989 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285042 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285043 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285062 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285064 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285082 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285130 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285151 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285171 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285190 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285204 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285238 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285245 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285292 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285304 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285323 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285329 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285338 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285382 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285437 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285505 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285537 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285560 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285565 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285589 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285599 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285608 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285612 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285625 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285628 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285629 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285641 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285645 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285655 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285677 is running.
# Sample =  SRR18379095 , Gene id = ENSG00000285679  is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285702 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285708 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285710 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285725 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285761 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285762 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285772 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285779 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285791 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285816 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285824 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285827 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285830 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285851 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285854 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285865 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285868 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285884 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285897 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285909 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285934 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285938 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285953 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285976 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000285982 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286001 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286010 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286019 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286030 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286050 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286067 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286070 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286075 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286085 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286104 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286105 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286112 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286122 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286130 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286149 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286155 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286161 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286181 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286185 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286190 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286219 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286224 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286234 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286235 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286259 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286264 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286267 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286268 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286320 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286331 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286360 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286430 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286485 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286503 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286588 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286688 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286729 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286739 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286786 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286797 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286819 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286827 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286838 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286870 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286918 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286921 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286940 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286992 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000286994 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287070 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287074 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287106 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287170 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287216 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287263 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287284 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287356 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287377 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287382 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287387 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287490 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287510 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287542 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287553 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287576 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287608 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287643 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287644 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287765 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287808 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287809 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287856 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287916 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287952 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287967 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000287979 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288000 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288012 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288044 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288053 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288076 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288271 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288473 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288529 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288531 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288542 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288564 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288592 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288604 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288614 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288622 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288623 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288632 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288643 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288654 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288661 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288663 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288665 is running.
# Sample = SRR18379095  , Gene id =  ENSG00000288675 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288681 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288684 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288686 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288709 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288715 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288722 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288752 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288829 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288851 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288857 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288867 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288871 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288873 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288891 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288905 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288914 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288920 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288924 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288928 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288934 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288970 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288994 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000288995 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289006 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289023 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289027 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289047 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289083 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289100 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289137 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289143 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289156 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289171 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289187 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289191 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289206 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289269 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289298 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289306 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289310 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289331 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289341 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289346 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289360 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289370 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289396 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289397 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289410 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289444 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289474 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289517 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289519 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289549 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289565 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289600 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289606 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289614 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289618 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289694 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289698 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289700 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289720 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289733 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289740 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289741 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289744 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289746 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289750 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289768 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289788 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289810 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289826 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289837 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289880 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289891 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289901 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000289964 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290018 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290021 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290036 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290039 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290082 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290123 is running.
# Sample =  SRR18379095 , Gene id =  ENSG00000290124 is running.
# ========================Sample SRR18379095 is Done========================

# %%
### This function combines feature vectors and constructs the final feature matrix.
from DOLPHIN.graph_generation.process_feature_matrix import run_feature_combination

# %%
run_feature_combination(
    metadata_path="./fsla_meta.csv",
    graph_directory="./06_graph_mtx",
    gene_annotation="./dolphin_exon_gtf/dolphin_gene_meta.csv",
    gtf_pkl_path="./dolphin_exon_gtf/dolphin.exon.pkl",
    out_directory="./",
    out_name= "fsla",
    clean_temp=False
)
# Out:
# Start Combining Feature Matrix...
# Combining Features:   0%|          | 0/450 [00:00<?, ?it/s]
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part1.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_gtf_an.gene_name.fillna(df_gtf_an.Geneid, inplace=True)
# Combining Features:  22%|██▏       | 100/450 [01:03<06:27,  1.11s/it]/mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part1.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_gtf_an.gene_name.fillna(df_gtf_an.Geneid, inplace=True)
# Combining Features:  44%|████▍     | 200/450 [02:20<04:17,  1.03s/it]/mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part1.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_gtf_an.gene_name.fillna(df_gtf_an.Geneid, inplace=True)
# Combining Features:  67%|██████▋   | 300/450 [06:03<03:31,  1.41s/it]  /mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part1.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_gtf_an.gene_name.fillna(df_gtf_an.Geneid, inplace=True)
# Combining Features:  89%|████████▉ | 400/450 [07:19<00:55,  1.12s/it]/mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part1.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_gtf_an.gene_name.fillna(df_gtf_an.Geneid, inplace=True)
# Combining Features: 100%|██████████| 450/450 [07:51<00:00,  2.16it/s]/mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# Combining Features: 100%|██████████| 450/450 [08:00<00:00,  1.07s/it]
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_feature_matrix.py:85: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combine_anndata_fea = combine_anndata_fea.concatenate(_temp_ad, index_unique = None, batch_key = None)
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_feature_matrix.py:85: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combine_anndata_fea = combine_anndata_fea.concatenate(_temp_ad, index_unique = None, batch_key = None)
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_feature_matrix.py:85: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combine_anndata_fea = combine_anndata_fea.concatenate(_temp_ad, index_unique = None, batch_key = None)
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_feature_matrix.py:85: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combine_anndata_fea = combine_anndata_fea.concatenate(_temp_ad, index_unique = None, batch_key = None)
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/func_step01_fea_mat_main_part2.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_fea_comp_reorder["new_index"] = df_fea_comp_reorder.groupby(["gene_id"]).cumcount()+1
# /mnt/md0/kailu/anaconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:401: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(

# %%
### This function combines adjacency vectors and constructs the Adjacency matrix.
from DOLPHIN.graph_generation.process_adjacency_matrix import run_adjacency_combination

# %%
run_adjacency_combination(
    metadata_path="./fsla_meta.csv",
    graph_directory="./06_graph_mtx",
    adj_meta_file="/dolphin_exon_gtf/dolphin_adj_metadata_table.csv",
    out_directory="./",
    out_name= "fsla",
    clean_temp=False,
    adj_run_num=50,
    parallel=True 
)
# Out:
# Start Combining Adjacency Matrix...
# Running in parallel with batch size = 50 ...
# Processing batch: 0 → 50
# Processing batch: 50 → 100Processing batch: 100 → 102
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# [1/3] Finished batch
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'gene_name' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
# [2/3] Finished batch
# [3/3] Finished batch
# Merging .h5ad batches...
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_adjacency_matrix.py:89: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combined_adata = combined_adata.concatenate(ad, index_unique=None, batch_key=None)
# /mnt/md1/kailu/DOLPHIN/DOLPHIN/graph_generation/process_adjacency_matrix.py:89: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combined_adata = combined_adata.concatenate(ad, index_unique=None, batch_key=None)
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical

# %%
### This function convert adjacency matrix to compressed Adjacency matrix.
from DOLPHIN.graph_generation.process_adjacency_matrix_compress import run_adjacency_compression

# %%
run_adjacency_compression(
    metadata_path="./fsla_meta.csv",
    out_name= "fsla",
    out_directory="./",
    num_processes=1
)
# Out:
# Starting processing cell: SRR18388386

# %%
### This function combine comprssed adjacency matrix.
from DOLPHIN.graph_generation.process_adjacency_matrix_compress_combine import run_adjacency_compress_combination

# %%
run_adjacency_compress_combination(
    metadata_path= "/fsla_meta.csv",
    out_name= "fsla",
    out_directory="./",
    adj_run_num=50,
    clean_temp=False,
    parallel= True,
)
# Out:
# Start Combining Compressed Adjacency Matrix...
# Running in parallel with batch size = 10 ...
# 100%|██████████| 3/3 [20:59<00:00, 419.91s/it]
# Merging .h5ad batches...

# %%
### This function clean the final adjacency matrix.
from DOLPHIN.graph_generation.process_adjacency_matrix_final import run_adjacency_matrix_final

run_adjacency_matrix_final(
    out_name="fsla",
    out_directory="./"
)
# Out:
# Start Generating Final Adjacency Matrix...
# Processing gene batches: 100%|██████████| 62/62 [03:12<00:00,  3.10s/it]
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical

# %%
## This step is primarily used to select highly variable genes (HVGs) based on the gene count table.
## The final feature matrix and adjacency matrix will retain only these HVGs as input for the DOLPHIN model.
## This step is optional—it provides one way to select HVGs, but you are free to use your own selection method.

from DOLPHIN.graph_generation.process_raw_gene import run_raw_gene

# %%
run_raw_gene(
    metadata_path= "./fsla_meta.csv",
    featurecount_path= "./04_exon_gene_cnt",
    gtf_path="./dolphin_exon_gtf/dolphin.exon.gtf",
    out_name="fsla",
    out_directory="./")
# Out:
# 100%|██████████| 795/795 [09:52<00:00,  1.34it/s]
# /mnt/data/kailu9/miniconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ... storing 'celltype1' as categorical
# ... storing 'celltype2' as categorical
# ... storing 'GeneName' as categorical
# /mnt/data/kailu9/miniconda3/envs/DOLPHIN/lib/python3.10/site-packages/anndata/utils.py:264: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD115-1', 'SNORD115-2', 'SNORD115-3', 'SNORD115-4', 'SNORD115-5']
#   warnings.warn(

# %%
## This step is generate hvg selected feature matrix

from DOLPHIN.graph_generation.process_feature_hvg import run_feature_hvg

run_feature_hvg(
    out_name="fsla",
    out_directory="./")
# Out:
# /mnt/data/kailu9/miniconda3/envs/DOLPHIN/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# Keep 2000 genes
# The Final Feature Matrix Size is 795 Cells and 13979 exons

# %%
## This step generates the HVG-selected adjacency matrix.

from DOLPHIN.graph_generation.process_adjacency_hvg import run_adjacency_hvg

run_adjacency_hvg(
    out_name="fsla",
    out_directory="./")
# Out:
# Keep 2000 genes
# The Final Adjacency Matrix Size is 795 Cells with dimension of 415174
# 100%|██████████| 795/795 [17:30<00:00,  1.32s/it]

# %%
## This final step generates the model input

from DOLPHIN.graph_generation.process_graph_final import run_model_input

run_model_input(
    metadata_path= "/fsla_meta.csv",
    out_name="fsla",
    out_directory="./",
    celltypename="celltype1")
# Out:
# Start Construct Data Input for model input
# 100%|██████████| 200/200 [15:09<00:00,  4.55s/it]
